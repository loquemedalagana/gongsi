# %% [markdown]
# ## ✅ 실무 vs 공시에서의 SMTP, POP3, IMAP 차이
#
# | 구분 | 실무 개발자 | 공시 수험생 |
# | --- | --- | --- |
# | **SMTP** | `nodemailer`, `JavaMail`, `SES` 같은 라이브러리로 발송 | **Mail 송신 프로토콜**로 암기 필수 |
# | **POP3** | 거의 사용 안 함, 대부분 Gmail/Exchange에 맡김 | 수신 후 **메일을 클라이언트로 가져오고 서버에서 삭제**됨 |
# | **IMAP** | 모바일 앱/웹메일 사용 시 서버와 **동기화**되는 방식 | 메일은 서버에 **남아 있음** (POP3와 차이점 자주 출제) |
# | **심화 이해도** | 필요 없음 (포트, 인증, 상태코드 수준이면 충분) | **포트 번호, 상태유지 여부, 메시지 흐름** 등 세세히 출제됨 |
#
# ---
#
# ## 📫 실무자 입장 정리
#
# > SMTP: 메일을 보낸다
# >
# >
# > POP3: `메일을 가져오고 서버에서 지운다`
# >
# > IMAP: `메일을 동기화한다 (서버에 남는다)`
# >
#
# 이 정도만 알고 있으면 실무에는 충분합니다.
#
# ---
#
# ## 📘 공시에서 필요한 수준
#
# | 항목 | SMTP | POP3 | IMAP |
# | --- | --- | --- | --- |
# | 역할 | 메일 송신 | 메일 수신 (단순) | 메일 수신 (동기화) |
# | 포트 | TCP 25 (기본), 587 (보안), 465 (SSL) | TCP 110 | TCP 143 |
# | 연결 방식 | 상태 없음 | 상태 유지 안함 | 상태 유지 |
# | 서버 저장 | 안함 | 받으면 삭제 | 서버에 유지 |
# | 상태 유지 | ❌ | ❌ | ✅ |
# | 출제 포인트 | 송신/수신 구분, 포트 번호, 상태 유지 여부 |  |  |
#
# ---
#
# ### 💡 정리하면:
#
# - ✅ 실무자라면: **SMTP는 사용**, POP3/IMAP은 **사용자는 몰라도 백엔드 시스템이 알아서 처리**
# - 🚫 하지만 공시에서는: **POP3 vs IMAP 차이, 포트번호, 서버 상태 유지 여부까지 외워야 함**

# %%
from IPython.display import Image

# 이미지 파일 경로 설정
image_path = 'smtp_pop3_imap.png'

# 이미지 출력
Image(filename=image_path)
